# %%
cv2.__version__
# Out:
# '4.1.1'

# %%
cascPath = 'C:\\Users\\Jonathan\\AppData\\Local\\Programs\\Python\\Python37\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml'
detector = cv2.CascadeClassifier(cascPath)


#recognizer = cv2.face.createLBPHFaceRecognizer
#cv2.face.LBPHFaceRecognizer_create() change to createLBPHFaceRecognizer


recognizer = cv2.face.LBPHFaceRecognizer_create()

# %%
path = 'C:\\Users\\Jonathan\\computer vision\\beckhamtrumpkim'

def getImagesAndLabels(path):
    imagePaths = [os.path.join(path,f) for f in os.listdir(path)] 
    faceSamples=[]
    ids = []
    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L')
        img_numpy = np.array(PIL_img,'uint8')
        #PIL_img.show()
        print(imagePath)
        id = int(os.path.split(imagePath)[-1].split(".")[0])
        faces = detector.detectMultiScale(img_numpy)
        print(id)
        print(faces)
        for (x,y,w,h) in faces:
            faceSamples.append(img_numpy[y:y+h,x:x+w])
            ids.append(id)
            #print(ids)
            
    return faceSamples,ids
faces,ids = getImagesAndLabels(path)
type(faces)
faces
# Out:
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.0.JPG
# 0
# [[132  98 207 207]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.1.JPG
# 0
# [[104  49  72  72]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.2.JPG
# 0
# [[234 135 243 243]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.3.jpg
# 0
# [[116  38  79  79]
#  [110 122  60  60]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.4.jpg
# 0
# [[71 21 32 32]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.5.jpg
# 0
# [[ 68  36 110 110]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.0.JPG
# 1
# [[111  35  63  63]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.1.JPG
# 1
# [[332  93 159 159]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.2.JPG
# 1
# [[305  78 324 324]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.3.JPG
# 1
# [[188 139 278 278]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.4.jpg
# 1
# [[110  86  50  50]]
# ...

# %%
from matplotlib import pyplot
from matplotlib.image import imread
imagePath = 'C:\\Users\\Jonathan\\computer vision\\beckhamtrumpkim\\'

plt.subplot(6,6,1)
filename = imagePath + '0.0.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,2)
filename = imagePath + '0.1.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,3)
filename = imagePath + '0.2.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,4)
filename = imagePath + '0.3.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,5)
filename = imagePath + '0.4.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,6)
filename = imagePath + '0.5.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)

plt.subplot(6,6,7)
filename = imagePath + '1.0.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,8)
filename = imagePath + '1.1.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,9)
filename = imagePath + '1.2.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,10)
filename = imagePath + '1.3.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,11)
filename = imagePath + '1.4.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,12)
filename = imagePath + '1.5.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,13)
filename = imagePath + '2.0.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,14)
filename = imagePath + '2.1.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
plt.subplot(6,6,15)
filename = imagePath + '2.2.jpg'
image = imread(filename)
print(filename)
plt.imshow(image)
# Out:
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.0.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.1.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.2.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.3.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.4.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.5.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.0.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.1.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.2.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.3.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.4.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.5.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\2.0.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\2.1.jpg
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\2.2.jpg

# %%
i = 0
for j in range(6):
    k = i*6 + j 
    print(k)
    plt.subplot(360+1+k)
    filename = imagePath + str(i) + '.'+ str(j)+'.jpg'
    image = imread(filename)
    print(filename)
    plt.imshow(image)
i = 1
for j in range(6):
    k = i*6 + j 
    print(k)
    plt.subplot(360+1+k)
    filename = imagePath + str(i) + '.'+ str(j)+'.jpg'
    image = imread(filename)
    print(filename)
    plt.imshow(image)

# %%
for i in range(len(ids)):
    print(faces[i].size)
# Out:
# 42849
# 5184
# 59049
# 6241
# 3600
# 1024
# 12100
# 3969
# 25281
# 104976
# 77284
# 2500
# 3844
# 22500
# 65536
# 36481

# %%
print ("\n [INFO] Training faces. It will take a few seconds. Wait ...")

recognizer.train(faces, np.array(ids)) #the label must be number........????

# Save the model into trainer/trainer.yml
recognizer.save('C:\\Users\\Jonathan\\facial_recognition\\trainer.yml') # recognizer.save() worked on Mac, but not on Pi

# Print the numer of faces trained and end program
print("\n [INFO] {0} faces trained. Exiting Program".format(len(np.unique(ids))))


#id = int(os.path.split(imagePath)[-1].split(".")[1])
# Out:
#  [INFO] Training faces. It will take a few seconds. Wait ...
#
#  [INFO] 3 faces trained. Exiting Program

# %%
imgloc = 'C:\\Users\\Jonathan\\computer vision\\beckhamtrumpkim\\1.2.JPG'
gray = cv2.imread(imgloc)
faces = detector.detectMultiScale(gray)# For each face
for (x, y, w, h) in faces: 
    # Draw rectangle around the face
    cv2.rectangle(gray, (x, y), (x+w, y+h), (255, 255, 255), 3)

#plt.figure(figsize=(12,8))
#plt.imshow(gray, cmap='gray')
plt.imshow(gray)
plt.show()

# %%
imgloc = 'C:\\Users\\Jonathan\\computer vision\\beckhamtrumpkim\\2.2.JPG'
gray = cv2.imread(imgloc)
grayimage2 = cv2.cvtColor(gray,cv2.COLOR_BGR2GRAY)
faces = detector.detectMultiScale(grayimage2,scaleFactor=1.1, minNeighbors = 5)

for (x, y, w, h) in faces: 
    # Draw rectangle around the face
    cv2.rectangle(grayimage2, (x, y), (x+w, y+h), (255, 255, 255), 3)

#plt.figure(figsize=(12,8))
plt.imshow(grayimage2, cmap='gray')
plt.show()

# %%
def puttext(test_image, text, x, y):
    cv2.putText(test_image, text, (x,y),cv2.FONT_HERSHEY_DUPLEX,2,(255,0,0),4)
    
def facedetection(test_img):
    grayimage2 = cv2.cvtColor(test_img,cv2.COLOR_BGR2GRAY)
    
    # using these parameters more accurate
    faces = detector.detectMultiScale(grayimage2,scaleFactor=1.1, minNeighbors = 5)
#    faces = detector.detectMultiScale(
#        grayimage2,
#       scaleFactor= 1.16,
#        minNeighbors=35,
#        minSize=(25, 25),
#        flags=cv2.CASCADE_SCALE_IMAGE
#    )
    
    return(faces,grayimage2)

# %%
imgloc = 'C:\\Users\\Jonathan\\computer vision\\facial_recognition xml\\2.7.JPG'
gray = cv2.imread(imgloc)

testface, testimage = facedetection(gray)
print('number of faces = {0} '.format(len(testface)))

for (x, y, w, h) in testface: 
    # Draw rectangle around the face
    cv2.rectangle(testimage, (x, y), (x+w, y+h), (255, 255, 255), 3)

plt.figure(figsize=(12,8))
plt.imshow(testimage, cmap='gray')
plt.show()
# Out:
# number of faces = 2

# %%
path = 'C:\\Users\\Jonathan\\computer vision\\beckhamtrumpkim'
faces, faceid = getImagesAndLabels(path)

def train_classifier(faces, faceID):
    face_recognizer=cv2.face.LBPHFaceRecognizer_create() #LBPHFaceRecognizer_create no such module
    face_recognizer.train(faces, np.array(faceID))
    return face_recognizer


# facerecognizer.write('trainingdata.yml')
# Out:
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.0.JPG
# 0
# [[132  98 207 207]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.1.JPG
# 0
# [[104  49  72  72]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.2.JPG
# 0
# [[234 135 243 243]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.3.jpg
# 0
# [[110 122  60  60]
#  [116  38  79  79]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.4.jpg
# 0
# [[71 21 32 32]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\0.5.jpg
# 0
# [[ 68  36 110 110]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.0.JPG
# 1
# [[111  35  63  63]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.1.JPG
# 1
# [[332  93 159 159]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.2.JPG
# 1
# [[305  78 324 324]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.3.JPG
# 1
# [[188 139 278 278]]
# C:\Users\Jonathan\computer vision\beckhamtrumpkim\1.4.jpg
# 1
# [[110  86  50  50]]
# ...

# %%
facerecognizer = train_classifier(faces, faceid)
xmlp = "C:\\Users\\Jonathan\\computer vision\\facial_recognition xml\\trainingdata.yml"
fs = cv2.FileStorage(xmlp, cv2.FILE_STORAGE_WRITE)

# %%
name = {0:"Beckham", 1:"Trump", 2:"Kim"}
imgloc = 'C:\\Users\\Jonathan\\computer vision\\facial_recognition xml\\beckham4.JPG'
gray = cv2.imread(imgloc)
#testface, testimage = facedetection(gray)
grayimage2 = cv2.cvtColor(gray,cv2.COLOR_BGR2GRAY)
faces = detector.detectMultiScale(grayimage2,scaleFactor=1.1, minNeighbors = 5)
plt.imshow(grayimage2)
plt.show()

# %%
name = {0:"Beckham", 1:"Trump", 2:"Kim"}
imgloc = 'C:\\Users\\Jonathan\\computer vision\\facial_recognition xml\\myself.jpg'
gray = cv2.imread(imgloc)

#testface, testimage = facedetection(gray)
grayimage2 = cv2.cvtColor(gray,cv2.COLOR_BGR2GRAY)
faces = detector.detectMultiScale(grayimage2,scaleFactor=1.2, minNeighbors = 2)

print('number of faces = {0} '.format(len(faces)))
plt.imshow(gray)
plt.show()


def put_text(test_img,text,x,y): 
    cv2.putText(test_img,text,(x,y),cv2.FONT_HERSHEY_DUPLEX,2,(255,255,0),3) 



for face in faces:
    (x,y,w,h) = face
    print(x,y,w,h)
    roi_gray = grayimage2[y:y+h, x:x+h]
    plt.imshow(roi_gray, cmap='gray')
    plt.show()
    label, confidence = facerecognizer.predict(roi_gray)
    
    print("confidence:", confidence)
    print("label:", label)
#     draw_rect(test_img,face)
    cv2.rectangle(grayimage2, (x, y), (x+w, y+h), (255, 255, 0), 50)
    predicted_name = name[label]
    print(predicted_name)
    put_text(gray, predicted_name,x,y)
    
#resized_img= cv2.resize(testimage,(2000,2000))
#plt.imshow(resized_img)
plt.imshow(gray)
# Out:
# number of faces = 1
# 109 112 121 121
# confidence: 82.59881439893637
# label: 1
# Trump
