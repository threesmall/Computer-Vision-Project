# %%
import cv2
import matplotlib.pyplot as plt

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Jonathan\Anaconda5
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.5                |           py36_0         3.0 MB
#     cycler-0.10.0              |   py36h009560c_0          13 KB
#     kiwisolver-1.0.1           |   py36h6538335_0          61 KB
#     matplotlib-2.2.2           |   py36had4c4a9_2         6.5 MB
#     pyparsing-2.4.0            |             py_0          58 KB
#     ------------------------------------------------------------
#                                            Total:         9.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/win-64::cycler-0.10.0-py36h009560c_0
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.0.1-py36h6538335_0
# ...

# %%
imgloc = 'C:\\Users\\Jonathan\\facial_david.JPG'
gray = cv2.imread(imgloc)
plt.figure(figsize=(12,8))
plt.imshow(gray, cmap='gray')

# %%
cascPath = 'C:\\Users\\Jonathan\\AppData\\Local\\Programs\\Python\\Python37\\Lib\\site-packages\\cv2\\data\\haarcascade_frontalface_default.xml'
faceCascade = cv2.CascadeClassifier(cascPath)

# %%
faces = faceCascade.detectMultiScale(
gray,
scaleFactor=1.1,
minNeighbors=5,
flags=cv2.CASCADE_SCALE_IMAGE
)# For each face
for (x, y, w, h) in faces: 
    # Draw rectangle around the face
    cv2.rectangle(gray, (x, y), (x+w, y+h), (255, 255, 255), 3)

# %%
plt.figure(figsize=(12,8))
plt.imshow(gray, cmap='gray')
plt.show()

# %%
eyePath = "C:\Users\Jonathan\AppData\Local\Programs\Python\Python37\Lib\site-packages\cv2\data\haarcascade_eye.xml"
smilePath = "C:\Users\Jonathan\AppData\Local\Programs\Python\Python37\Lib\site-packages\cv2\data\haarcascade_smile.xml"

eyeCascade = cv2.CascadeClassifier(eyePath)
smileCascade = cv2.CascadeClassifier(smilePath)
# Out:
#   File "<ipython-input-37-077217142400>", line 1
#     eyePath = "C:\Users\Jonathan\AppData\Local\Programs\Python\Python37\Lib\site-packages\cv2\data\haarcascade_eye.xml"
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
conda install -c conda-forge dlib=19.4
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Jonathan\Anaconda5
#
#   added / updated specs:
#     - dlib=19.4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.7.8                |           py36_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-0 --> conda-forge::ca-certificates-2019.6.16-hecc5488_0
#   certifi               pkgs/main::certifi-2019.6.16-py36_0 --> conda-forge::certifi-2019.6.16-py36_1
#   conda                       pkgs/main::conda-4.7.5-py36_0 --> conda-forge::conda-4.7.8-py36_0
# ...

# %%
import dlib

# %% [markdown]
# **Using HOG dlib**

# %%
face_detect = dlib.get_frontal_face_detector()
imgloc = 'C:\\Users\\Jonathan\\facial_davidfamily.JPG'
gray = cv2.imread(imgloc)
plt.imshow(gray)

def rect_to_bb(rect):
    # take a bounding predicted by dlib and convert it
    # to the format (x, y, w, h) as we would normally do
    # with OpenCV
    x = rect.left()
    y = rect.top()
    w = rect.right() - x
    h = rect.bottom() - y

    # return a tuple of (x, y, w, h)
    return (x, y, w, h)


rects  = face_detect(gray, 1)
#printing the number of face
print(len(rects))


for (i, rect) in enumerate(rects):
    (x, y, w, h) = rect_to_bb(rect)
    print(i, x, y, w, h)
    cv2.rectangle(gray, (x, y), (x + w, y + h), (0, 255, 0), 2)
    
plt.figure(figsize=(12,8))
plt.imshow(gray, cmap='gray')
plt.show()
# Out:
# 6
# 0 487 94 63 62
# 1 294 156 62 62
# 2 262 291 52 52
# 3 193 101 52 52
# 4 366 90 51 51
# 5 619 135 62 63
